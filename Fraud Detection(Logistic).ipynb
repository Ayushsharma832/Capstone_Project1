# %%
import pandas as pd

# %%
df = pd.read_csv('E:\EXL Training\creditcard.csv')

# %%
# df.describe()
# df.info()
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()
#means highly unbalanced
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
legit.Amount
#same as legit['Amount']
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284315, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#so will have to take only 492 random transaction from legit also  
legit = legit.sample(n=492)

# %%
#now concat both legit and fraud
df_new = pd.concat([legit,fraud])
df_new.head()
#index have changed as took random samples and thier index is added
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 222970  143200.0  1.649191 -1.468348 -2.110016 -1.707481  1.423896  3.518279
# 28025    34817.0 -0.146865 -2.069787 -0.141020  1.545439 -0.962905  0.453037
# 128865   78867.0 -0.948937  1.435865 -0.023430  0.782389 -0.659430  0.341196
# 233735  147684.0  2.134792 -1.106434 -0.895082 -1.338412 -1.174314 -1.064208
# 62984    50502.0 -1.495984  1.080319  0.673051 -1.776777  0.252788 -0.087843
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 222970 -0.922922  0.907990  1.301395  ... -0.056565 -0.616305  0.274676
# 28025   0.495834  0.138371  0.085389  ...  0.248247 -0.903449 -0.474213
# 128865  0.186839  0.865480 -0.940648  ...  0.276115  0.550733  0.000028
# 233735 -0.710449 -0.212003  0.440407  ... -0.360671 -0.443414  0.277390
# 62984   0.241777  0.410071  0.371473  ... -0.214060 -0.394642 -0.082676
#
# ...

# %%
df_new.groupby('Class').mean()
#almost same mean as in df(will use this diff. in mean to classifiy raud and not fraud)
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96287.922764  0.024394 -0.074541  0.034848  0.090629  0.030552
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.075334  0.013519  0.092550  0.034269  ...  0.000052  0.011172
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0      0.001568  0.005393 -0.00008 -0.019173  0.012360  0.019751  0.001261
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       95.841931
# 1      122.211321
#
# [2 rows x 30 columns]
